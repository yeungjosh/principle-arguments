# %%
import numpy as np
import pandas as pd
from nltk.tokenize import word_tokenize

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/luongminh97/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
df = pd.read_csv("CoPA-Motion-Labeling.csv")
len(df.keys())
# Out:
# 43

# %%
CoPAs = pd.read_csv('principle_argument_CoPA/PA_list.txt', header=None, sep='$', squeeze=True)

# %%
claimstance = pd.read_csv('IBM_Claim_Stance/claim_stance_dataset_v1.csv')

# %%
claimstance.keys()
# Out:
# Index(['topicId', 'split', 'topicText', 'topicTarget', 'topicSentiment',
#        'claims.claimId', 'claims.stance', 'claims.claimCorrectedText',
#        'claims.claimOriginalText', 'claims.article.rawFile',
#        'claims.article.rawSpan.start', 'claims.article.rawSpan.end',
#        'claims.article.cleanFile', 'claims.article.cleanSpan.start',
#        'claims.article.cleanSpan.end', 'claims.Compatible',
#        'claims.claimTarget.text', 'claims.claimTarget.span.start',
#        'claims.claimTarget.span.end', 'claims.claimSentiment',
#        'claims.targetsRelation'],
#       dtype='object')

# %%
corrected = claimstance["claims.claimCorrectedText"].apply(lambda row: row.lower()).apply(word_tokenize)

# %%
vocab = set()

# %%
for row in corrected:
    vocab.update(row)

# %%
sorted(list(vocab))
# Out:
# ['%',
#  '&',
#  "'",
#  "''",
#  "'artificial",
#  "'crimes",
#  "'defamation",
#  "'is",
#  "'punish",
#  "'punishing",
#  "'re",
#  "'ruin",
#  "'s",
#  '(',
#  ')',
#  ',',
#  '-',
#  '.',
#  '..',
#  '10,000',
#  '100',
#  '1967',
#  '1979',
#  '200,000',
#  '2011',
#  '20th',
#  '21st',
#  '2–3',
#  '8th',
#  ':',
#  ';',
#  '?',
#  '[',
#  ']',
#  '`',
#  '``',
#  'a',
#  'abandon',
#  'abandonment',
#  'abdication',
#  'abilities',
#  'ability',
#  'able',
#  'abnormal',
#  'abolishing',
#  'abolition',
#  'abort',
#  'abortion',
#  'abortions',
#  'about',
#  'above',
#  'abridged',
#  'abroad',
#  'abrogation',
#  'absence',
#  'absolute',
#  'absolutely',
#  'abstinence',
#  'abstinence-only',
#  'abstinence-only-until-marriage',
#  'absurd',
#  'abundant',
#  'abuse',
#  'abusers',
#  'abuses',
#  'abusive',
#  'academic',
#  'academics',
#  'accept',
#  'acceptable',
#  'acceptance',
#  'accepted',
#  'accepting',
#  'access',
#  'accidents',
#  'accommodate',
# ...

# %%
CoPAs = CoPAs.apply(lambda row: row.lower()).apply(word_tokenize)

# %%
for row in CoPAs:
    vocab.update(row)
